# %% [markdown]
# <a href="https://colab.research.google.com/github/jovidialaviosa/word-cloud/blob/main/Word_Cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
#% matplotlib inline# Load in the dataframe
#df = pd.read_csv("data-train-pbd - data-train-pbd.csv", delimiter=';', encoding='utf-8')
df = pd.read_csv("data-train-pbd - data-train-pbd.csv")

# %%
df
# Out:
#            object_name                                               link  \
# 0       oei hwie siang  https://twitter.com/anaknyaslamet/status/17523...
# 1                #OIKN            https://www.instagram.com/p/C70RYopIdKG
# 2                #OIKN            https://www.instagram.com/p/C70JZ3zpITx
# 3                #OIKN            https://www.instagram.com/p/C7z60b_S8WL
# 4                #OIKN            https://www.instagram.com/p/C7zSVBttGsC
# ...                ...                                                ...
# 99995  petani tembakau  https://twitter.com/MitchellCh36585/status/174...
# 99996  petani tembakau  https://twitter.com/franclynbea/status/1745434...
# 99997  petani tembakau  https://twitter.com/VeltreaPoindext/status/174...
# 99998  petani tembakau  https://twitter.com/bernardalfiler/status/1745...
# 99999  petani tembakau  https://twitter.com/oasdmemartins/status/17454...
#
#                 aspect                                            content  \
# ...

# %%
# Specify the path for the output CSV file
output_csv_path = "data-train-pbd - data-train-pbd.csv"

# Save the DataFrame to the CSV file
df.to_csv(output_csv_path, index=False)

# Display a message indicating that the CSV file has been saved
print(f"The DataFrame has been successfully saved to {output_csv_path}.")
# Out:
# The DataFrame has been successfully saved to data-train-pbd - data-train-pbd.csv.

# %%
df_djarum = df[df['aspect'] == 'harga rokok']

df_djarum
# Out:
#        object_name                                               link  \
# 1363   harga rokok  https://twitter.com/akusukabiru03/status/18050...
# 1364   harga rokok  https://twitter.com/alonahalona/status/1804908...
# 1365   harga rokok  https://twitter.com/sondebetabeta/status/18048...
# 1366   harga rokok  https://twitter.com/arzenaers/status/180447392...
# 1367   harga rokok  https://twitter.com/YK89SAYU/status/1804454002...
# ...            ...                                                ...
# 46651  #hargarokok            https://www.instagram.com/p/C1lMNmaSoqV
# 46652  #hargarokok            https://www.instagram.com/p/C1lC01My5mH
# 46653  #hargarokok            https://www.instagram.com/p/C1lA5nthDVQ
# 46654  #hargarokok            https://www.instagram.com/p/C1jN-MlLZrt
# 46655  #hargarokok            https://www.instagram.com/p/C1iwGwMP-1Z
#
#             aspect                                            content  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 100000.

# %%
df_selected = df_djarum[['content']]
df_selected
# Out:
#                                                  content
# 1363   Rokok ayah semenjak harga rokok yg biasa ayah ...
# 1364   @undrcvr_agent__ @minervamagellan *mengingat h...
# 1365   @alfiantomyyy @Heraloebss UDAH TAU ORANG KECIL...
# 1366   @Virgomanggala Ketoke mergo harga rokok naik t...
# 1367   Kehabisan Rokok , beli rokok dulu ! Mahal maha...
# ...                                                  ...
# 46651  Harga rokok Januari 2024¬mengalami kenaikan u...
# 46652  Tarif cukai hasil tembakau (CHT) resmi naik pa...
# 46653  Kenaikan CHT rata-rata 10% ini telah mempertim...
# 46654  Resmi Naik per 1 Januari 2024, Berikut Daftar ...
# 46655  Para perokok tembakau dan perokok elektrik men...
#
# [2604 rows x 1 columns]

# %% [markdown]
# # Word CLoud

# %%
# !pip install wordcloud matplotlib

# %%
import nltk
from nltk.corpus import stopwords
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download NLTK stopwords for Indonesian
nltk.download('stopwords')
stop_words_indonesian = set(stopwords.words('indonesian'))

# Kata-kata tambahan yang ingin dihapus
additional_stopwords = {'djarum','yg', 'ga', 'gak', 'aja','ini', 'sdh', 'ya', 'utk', 'tdk', 'gw', 'sy', 'dgn', 'kalo', 'n', 'nya', 'jgn', 'amp', 'djarum', 'ya', 'sih', 'ü', 'gue', 'klo', 'ini', 'emang'}

# Gabungkan stopwords dari NLTK dengan kata-kata tambahan yang ingin dihapus
stop_words_indonesian = stop_words_indonesian.union(additional_stopwords)

# Custom function to remove Twitter handles, links, and specified stopwords
def clean_text_custom(text):
    # Remove words containing '@' (Twitter handles)
    text = ' '.join([word for word in text.split() if '@' not in word])
    # Remove words containing 'https' (links)
    text = re.sub(r'https\S+', '', text)
    # Remove specified stopwords
    text = ' '.join([word for word in text.split() if word.lower() not in stop_words_indonesian])
    return text

# Apply the custom function to remove Twitter handles, links, and specified stopwords
df_selected['cleaned_text_custom'] = df_selected['content'].apply(clean_text_custom)

# Concatenate all the cleaned tweets into a single string
all_cleaned_text = ' '.join(df_selected['cleaned_text_custom'])

# Generate the word cloud with a maximum of 50 words
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=50).generate(all_cleaned_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
